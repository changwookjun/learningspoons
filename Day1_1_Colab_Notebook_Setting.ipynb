# %% [markdown]
# # Colab 환경 설정 방법
# <b> colab에 기본적인 설명을 하는 페이지이다.
# <b> Link를 클릭하면 구글 계정을 로그인 하도록 유도한다.
#
#   [  https://colab.research.google.com/ ](https://colab.research.google.com/)

# %% [markdown]
# ## 구글 드라이브에 있는 이미지를 불러오기 위해서 구글 드라이브 마운트 하기
# <b> Google Drive 연결 방법 (URL을 누르면 인증키 발급 -> Enter verification code에 입력하기)
# <b> 두번 코드를 입력한다.
# <b>   Mounted at /content/gdrive 를 확인 한다.

# %%
from google.colab import auth
auth.authenticate_user()

from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=email%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdocs.test%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive.photos.readonly%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /content/gdrive

# %% [markdown]
# ## PYTHON3  노트북 만들기

# %%
from IPython.display import Image
Image('/content/gdrive/My Drive/Colab Notebooks/Images/1.png', width=800, height=600)

# %% [markdown]
# ## GPU 확인 하기 (Tesla T4 확인)

# %%
# !nvidia-smi
# Out:
# Thu May 30 02:04:43 2019
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 418.67       Driver Version: 410.79       CUDA Version: 10.0     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   45C    P8    15W /  70W |      0MiB / 15079MiB |      0%      Default |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                       GPU Memory |
# ...

# %% [markdown]
# ## GPU 설정 하기

# %%
from IPython.display import Image
Image('/content/gdrive/My Drive/Colab Notebooks/Images/2.png', width=800, height=600)

# %% [markdown]
# ## GPU 이름 출력 하기

# %%
import tensorflow as tf

tf.test.gpu_device_name()
# Out:
# '/device:GPU:0'

# %% [markdown]
# ## 경로에 파일 보기 (현재 드라이브 경로에 위치한 파일 정보)

# %%
# !ls -al
# Out:
# total 36
# drwxr-xr-x 1 root root 4096 May 30 02:06 .
# drwxr-xr-x 1 root root 4096 May 30 01:37 ..
# -rw-r--r-- 1 root root 2529 May 30 01:38 adc.json
# drwxr-xr-x 1 root root 4096 May 30 01:38 .config
# drwx------ 3 root root 4096 May 30 01:39 gdrive
# drwxr-xr-x 2 root root 4096 May 30 02:06 Images
# drwxr-xr-x 1 root root 4096 May 24 16:08 sample_data

# %% [markdown]
# ## 현재 경로 보기 (간단한 명령어 사용)

# %%
# !pwd
# Out:
# /content

# %% [markdown]
# ##  폴더 만들기 방법

# %%
# !mkdir Images

# %%
# !ls -al
# Out:
# total 36
# drwxr-xr-x 1 root root 4096 May 30 02:06 .
# drwxr-xr-x 1 root root 4096 May 30 01:37 ..
# -rw-r--r-- 1 root root 2529 May 30 01:38 adc.json
# drwxr-xr-x 1 root root 4096 May 30 01:38 .config
# drwx------ 3 root root 4096 May 30 01:39 gdrive
# drwxr-xr-x 2 root root 4096 May 30 02:06 Images
# drwxr-xr-x 1 root root 4096 May 24 16:08 sample_data

# %% [markdown]
# # 생성된 Colab Notebooks이 있는 경로

# %%
# !ls "/content/gdrive/My Drive/Colab Notebooks"
# Out:
#  Data
#  Day1_1_Colab_Notebook_Setting.ipynb
#  Day1_2_Feed_Dict.ipynb
#  Day1_3_tf_data.ipynb
#  Day1_4_Session.ipynb
#  Day1_5_Estimator.ipynb
#  Day2_1_One_Hot_Encoding.ipynb
#  Day2_2_Bag_Of_Words.ipynb
# 'Day2_3_Word2Vec(CBOW).ipynb'
# 'Day2_4_Word2Vec(skip_gram).ipynb'
#  Day2_5_gensim_word2vec.ipynb
#  Day3_1_Naver_Movie_Review_EDA_Preprocessing.ipynb
#  Day3_2_Yoon_Kim_Model.ipynb
#  Day3_3_Char_CNN.ipynb
#  Day4_1_Text_Similarity_EDA_Preprocessing.ipynb
#  Day4_2_Ma_LSTM.ipynb
#  Day4_3_XGBoost.ipynb
#  Day5_1_seq2seq.ipynb
#  Day6_1_Attention.ipynb
#  Day6_2_seq2seq_visualization.ipynb
#  Day7_1_Transformer.ipynb
#  Day7_2_Transformer_advance.ipynb
#  Font
#  Images
#  Seq2seq
#  Slide
#  Transformer

# %%
#%cd "/content/gdrive/My Drive/Colab Notebooks"

# %% [markdown]
# ## Tensorflow 확인 하기

# %%
import tensorflow as tf
tf.__version__
# Out:
# '1.13.1'

# %% [markdown]
# ## System 정보 보기 (Xeon 2.30GHz)

# %%
# !cat /proc/cpuinfo
# Out:
# processor	: 0
# vendor_id	: GenuineIntel
# cpu family	: 6
# model		: 63
# model name	: Intel(R) Xeon(R) CPU @ 2.30GHz
# stepping	: 0
# microcode	: 0x1
# cpu MHz		: 2300.000
# cache size	: 46080 KB
# physical id	: 0
# siblings	: 2
# core id		: 0
# cpu cores	: 1
# apicid		: 0
# initial apicid	: 0
# fpu		: yes
# fpu_exception	: yes
# cpuid level	: 13
# wp		: yes
# flags		: fpu vme de pse tsc msr pae mce cx8 apic sep mtrr pge mca cmov pat pse36 clflush mmx fxsr sse sse2 ss ht syscall nx pdpe1gb rdtscp lm constant_tsc rep_good nopl xtopology nonstop_tsc cpuid tsc_known_freq pni pclmulqdq ssse3 fma cx16 pcid sse4_1 sse4_2 x2apic movbe popcnt aes xsave avx f16c rdrand hypervisor lahf_lm abm invpcid_single pti ssbd ibrs ibpb stibp fsgsbase tsc_adjust bmi1 avx2 smep bmi2 erms invpcid xsaveopt arat arch_capabilities
# bugs		: cpu_meltdown spectre_v1 spectre_v2 spec_store_bypass l1tf
# bogomips	: 4600.00
# clflush size	: 64
# cache_alignment	: 64
# ...

# %% [markdown]
# # Memory 13G

# %%
# !cat /proc/meminfo
# Out:
# MemTotal:       13335268 kB
# MemFree:        10151280 kB
# MemAvailable:   12078440 kB
# Buffers:           76812 kB
# Cached:          1984116 kB
# SwapCached:            0 kB
# Active:          1001420 kB
# Inactive:        1790024 kB
# Active(anon):     677980 kB
# Inactive(anon):     4440 kB
# Active(file):     323440 kB
# Inactive(file):  1785584 kB
# Unevictable:           0 kB
# Mlocked:               0 kB
# SwapTotal:             0 kB
# SwapFree:              0 kB
# Dirty:               600 kB
# Writeback:             0 kB
# AnonPages:        730656 kB
# Mapped:           514152 kB
# Shmem:              5004 kB
# Slab:             158508 kB
# SReclaimable:     118660 kB
# SUnreclaim:        39848 kB
# KernelStack:        4672 kB
# PageTables:         7268 kB
# NFS_Unstable:          0 kB
# Bounce:                0 kB
# WritebackTmp:          0 kB
# CommitLimit:     6667632 kB
# Committed_AS:    2683364 kB
# VmallocTotal:   34359738367 kB
# VmallocUsed:           0 kB
# ...
